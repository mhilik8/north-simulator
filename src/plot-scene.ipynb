# %%
import plotly.io as pio
pio.renderers.default = "jupyterlab"
from north.plots.scene import ScenePlotter

# %%
my_scene_plotter = ScenePlotter.from_physical_state(
    90.0,
    23.5,
    21.7,
    -17.3,
    192.4
)

# %%
my_scene_plotter.latitude_view.figure.show()

# %%
my_scene_plotter.latitude = -41.2
my_scene_plotter.update()

# %%
my_scene_plotter.azimuth_view.figure.show()

# %%
my_scene_plotter.azimuth = 163.1
my_scene_plotter.update()
