# %%
from north.plots.plot_latitude import latitude_view

latitude = 31.1

fig = latitude_view(latitude)
fig.show()

# %%
pitch, roll = -5.2, -6.2

# %%
from north.plots.plot_inclination import inclination_3d_view
fig2 = inclination_3d_view(pitch, roll)
fig2.show()

# %%
from north.plots.plot_inclination import inclination_gauge
fig3 = inclination_gauge(pitch, roll)
fig3.show()
